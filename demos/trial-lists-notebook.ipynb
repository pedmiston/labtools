# %% [markdown]
# # Making Trial Lists

# %%
import pandas as pd
import numpy as np

import sys, os
sys.path.insert(0, os.path.abspath('..'))

from resources.trials_functions import *

# %% [markdown]
# ## counterbalance

# %%
my_variables = {'version':['a','b','c'], 'response':[1,2], 'session':2}
counterbalance(my_variables, order=['version','session','response'])
# Out:
#   version  session  response
# 0       a        2         1
# 1       a        2         2
# 2       b        2         1
# 3       b        2         2
# 4       c        2         1
# 5       c        2         2

# %% [markdown]
# ## expand

# %%
posner = pd.DataFrame({'target_dir':['left','right']})
posner
# Out:
#   target_dir
# 0       left
# 1      right

# %%
posner = expand(posner, 'valid_prime', ratio=0.75)
posner
# Out:
#    valid_prime target_dir
# 0            1       left
# 1            1      right
# 2            1       left
# 3            1      right
# 4            1       left
# 5            1      right
# 6            0       left
# 7            0      right

# %%
posner = expand(posner, 'prime_type', values=['present', 'neutral'], ratio=0.5)
posner['valid_prime'][posner['prime_type'] == 'neutral'] = np.nan
posner
# Out:
#    prime_type  valid_prime target_dir
# 0     present            1       left
# 1     present            1      right
# 2     present            1       left
# 3     present            1      right
# 4     present            1       left
# 5     present            1      right
# 6     present            0       left
# 7     present            0      right
# 8     neutral          NaN       left
# 9     neutral          NaN      right
# 10    neutral          NaN       left
# 11    neutral          NaN      right
# 12    neutral          NaN       left
# 13    neutral          NaN      right
# 14    neutral          NaN       left
# 15    neutral          NaN      right

# %% [markdown]
# ## extend

# %%
extend(posner, reps = 2)
# Out:
#    prime_type  valid_prime target_dir
# 0     present            1       left
# 1     present            1      right
# 2     present            1       left
# 3     present            1      right
# 4     present            1       left
# 5     present            1      right
# 6     present            0       left
# 7     present            0      right
# 8     neutral          NaN       left
# 9     neutral          NaN      right
# 10    neutral          NaN       left
# 11    neutral          NaN      right
# 12    neutral          NaN       left
# 13    neutral          NaN      right
# 14    neutral          NaN       left
# 15    neutral          NaN      right
# 16    present            1       left
# 17    present            1      right
# 18    present            1       left
# 19    present            1      right
# 20    present            1       left
# 21    present            1      right
# 22    present            0       left
# 23    present            0      right
# 24    neutral          NaN       left
# 25    neutral          NaN      right
# 26    neutral          NaN       left
# 27    neutral          NaN      right
# 28    neutral          NaN       left
# 29    neutral          NaN      right
# 30    neutral          NaN       left
# 31    neutral          NaN      right

# %%
posner_full = extend(posner, max_length = 390, rep_ix = 'iteration')
len(posner_full)
# Out:
# 384
